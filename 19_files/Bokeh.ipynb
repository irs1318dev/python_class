# %% [markdown]
# # Importing Python Packages

# %%
# Import and set up Bokeh plotting package
import bokeh.io
import bokeh.models
import bokeh.plotting
import bokeh.resources
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# Pandas package for dataframes
import pandas as pd

# Tell Python where to find scouting system packages
# These lines are unnecessary if using PYTHONPATH environment variable
import sys
sys.path.append('C:/Users/stacy/OneDrive/Projects/scouting/scouting2017/irsScouting2017')

# Import scouting system packages
import server.model.event as event
import server.view.dataframes as dframes

# %% [markdown]
# # Setup the Scouting System

# %%
event.EventDal.set_current_event('wayak', 2018)
# Out:
# 25167

# %%
event.EventDal.set_current_match('060-q')
# Out:
# 'current match 060-q'

# %% [markdown]
# # Get a Dataframe

# %%
mdf = dframes.measure_summary_df()
mdf.head(24)
# Out:
#                                   matches  sum_successes  max_successes  \
# team phase  actor task
# 1318 auto   robot autoLine             12             10              1
#                   crossNull            12              0              0
#                   holdCube             12             12              1
#                   placeIncorrect       12              0              0
#                   placeScale           12              2              1
#                   placeSwitch          12              8              1
#      finish robot disabled             12              4              1
#             team  getFoul              12              0              0
#             robot makeClimb            12              6              1
#                   parkPlatform         12              2              1
#      teleop robot pickupCubeZone       12              8              2
#                   pickupFloor          12             16              5
#                   pickupPlatform       12             18              4
#                   pickupPortal         12             10              3
#                   placeOpponent        12             16              4
#                   placeScale           12             34              6
#                   placeSwitch          12              2              1
# 2148 auto   robot autoLine             12             10              1
#                   holdCube             12              2              1
#      finish robot disabled             12              0              0
#                   parkPlatform         12              6              1
#      teleop robot pickupCubeZone       12             34              5
#                   pickupFloor          12              2              1
#                   pickupPlatform       12              2              1
#
#                                   min_successes  count_successes  \
# team phase  actor task
# 1318 auto   robot autoLine                    1               10
#                   crossNull                   0                2
#                   holdCube                    1               12
#                   placeIncorrect              0                2
#                   placeScale                  1                2
#                   placeSwitch                 1                8
#      finish robot disabled                    0                6
#             team  getFoul                     0                2
#             robot makeClimb                   0                8
#                   parkPlatform                1                2
#      teleop robot pickupCubeZone              1                6
#                   pickupFloor                 1                8
#                   pickupPlatform              0               10
#                   pickupPortal                1                6
#                   placeOpponent               4                4
#                   placeScale                  1               12
#                   placeSwitch                 0                6
# 2148 auto   robot autoLine                    1               10
#                   holdCube                    1                2
#      finish robot disabled                    0                2
#                   parkPlatform                1                6
#      teleop robot pickupCubeZone              1               12
#                   pickupFloor                 1                2
#                   pickupPlatform              0                4
#
#                                   avg_successes  tav_successes  sum_attempts  \
# team phase  actor task
# 1318 auto   robot autoLine             0.833333       1.000000            10
#                   crossNull            0.000000       0.000000             0
#                   holdCube             1.000000       1.000000            12
#                   placeIncorrect       0.000000       0.000000             0
#                   placeScale           0.166667       1.000000             2
#                   placeSwitch          0.666667       1.000000             8
#      finish robot disabled             0.333333       0.666667             4
#             team  getFoul              0.000000       0.000000             0
#             robot makeClimb            0.500000       0.750000             8
#                   parkPlatform         0.166667       1.000000             2
#      teleop robot pickupCubeZone       0.666667       1.333333             8
#                   pickupFloor          1.333333       2.000000            16
#                   pickupPlatform       1.500000       1.800000            18
#                   pickupPortal         0.833333       1.666667            10
#                   placeOpponent        1.333333       4.000000            16
#                   placeScale           2.833333       2.833333            36
#                   placeSwitch          0.166667       0.333333             4
# 2148 auto   robot autoLine             0.833333       1.000000            10
#                   holdCube             0.166667       1.000000             2
#      finish robot disabled             0.000000       0.000000             2
#                   parkPlatform         0.500000       1.000000             6
#      teleop robot pickupCubeZone       2.833333       2.833333            34
#                   pickupFloor          0.166667       1.000000             2
#                   pickupPlatform       0.166667       0.500000             2
#
#                                   max_attempts  min_attempts  \
# team phase  actor task
# 1318 auto   robot autoLine                   1             1
#                   crossNull                  0             0
#                   holdCube                   1             1
#                   placeIncorrect             0             0
#                   placeScale                 1             1
#                   placeSwitch                1             1
#      finish robot disabled                   1             0
#             team  getFoul                    0             0
#             robot makeClimb                  1             1
#                   parkPlatform               1             1
#      teleop robot pickupCubeZone             2             1
#                   pickupFloor                5             1
#                   pickupPlatform             4             0
#                   pickupPortal               3             1
#                   placeOpponent              4             4
#                   placeScale                 6             1
#                   placeSwitch                1             0
# 2148 auto   robot autoLine                   1             1
#                   holdCube                   1             1
#      finish robot disabled                   1             1
#                   parkPlatform               1             1
#      teleop robot pickupCubeZone             5             1
#                   pickupFloor                1             1
#                   pickupPlatform             1             0
#
#                                         ...         min_cycle_times  \
# team phase  actor task                  ...
# 1318 auto   robot autoLine              ...                       0
#                   crossNull             ...                       0
#                   holdCube              ...                       0
#                   placeIncorrect        ...                       0
#                   placeScale            ...                       0
#                   placeSwitch           ...                       0
#      finish robot disabled              ...                       0
#             team  getFoul               ...                       0
#             robot makeClimb             ...                       0
#                   parkPlatform          ...                       0
#      teleop robot pickupCubeZone        ...                       0
#                   pickupFloor           ...                       0
#                   pickupPlatform        ...                       0
#                   pickupPortal          ...                       0
#                   placeOpponent         ...                       0
#                   placeScale            ...                       0
#                   placeSwitch           ...                       0
# 2148 auto   robot autoLine              ...                       0
#                   holdCube              ...                       0
#      finish robot disabled              ...                       0
#                   parkPlatform          ...                       0
#      teleop robot pickupCubeZone        ...                       0
#                   pickupFloor           ...                       0
#                   pickupPlatform        ...                       0
#
#                                   avg_cycle_times  tav_cycle_times  \
# team phase  actor task
# 1318 auto   robot autoLine                    0.0              0.0
#                   crossNull                   0.0              0.0
#                   holdCube                    0.0              0.0
#                   placeIncorrect              0.0              0.0
#                   placeScale                  0.0              0.0
#                   placeSwitch                 0.0              0.0
#      finish robot disabled                    0.0              0.0
#             team  getFoul                     0.0              0.0
#             robot makeClimb                   0.0              0.0
#                   parkPlatform                0.0              0.0
#      teleop robot pickupCubeZone              0.0              0.0
#                   pickupFloor                 0.0              0.0
#                   pickupPlatform              0.0              0.0
#                   pickupPortal                0.0              0.0
#                   placeOpponent               0.0              0.0
#                   placeScale                  0.0              0.0
#                   placeSwitch                 0.0              0.0
# 2148 auto   robot autoLine                    0.0              0.0
#                   holdCube                    0.0              0.0
#      finish robot disabled                    0.0              0.0
#                   parkPlatform                0.0              0.0
#      teleop robot pickupCubeZone              0.0              0.0
#                   pickupFloor                 0.0              0.0
#                   pickupPlatform              0.0              0.0
#
#                                   count_cycle_times  sum_capabilities  \
# team phase  actor task
# 1318 auto   robot autoLine                       10                 0
#                   crossNull                       2                 0
#                   holdCube                       12                 0
#                   placeIncorrect                  2                 0
#                   placeScale                      2                 0
#                   placeSwitch                     8                 0
#      finish robot disabled                        6                 0
#             team  getFoul                         2                 0
#             robot makeClimb                       8                 0
#                   parkPlatform                    2                 0
#      teleop robot pickupCubeZone                  6                 0
#                   pickupFloor                     8                 0
#                   pickupPlatform                 10                 0
#                   pickupPortal                    6                 0
#                   placeOpponent                   4                 0
#                   placeScale                     12                 0
#                   placeSwitch                     6                 0
# 2148 auto   robot autoLine                       10                 0
#                   holdCube                        2                 0
#      finish robot disabled                        2                 0
#                   parkPlatform                    6                 0
#      teleop robot pickupCubeZone                 12                 0
#                   pickupFloor                     2                 0
#                   pickupPlatform                  4                 0
#
#                                   max_capabilities  min_capabilities  \
# team phase  actor task
# 1318 auto   robot autoLine                       0                 0
#                   crossNull                      0                 0
#                   holdCube                       0                 0
#                   placeIncorrect                 0                 0
#                   placeScale                     0                 0
#                   placeSwitch                    0                 0
#      finish robot disabled                       0                 0
#             team  getFoul                        0                 0
#             robot makeClimb                      0                 0
#                   parkPlatform                   0                 0
#      teleop robot pickupCubeZone                 0                 0
#                   pickupFloor                    0                 0
#                   pickupPlatform                 0                 0
#                   pickupPortal                   0                 0
#                   placeOpponent                  0                 0
#                   placeScale                     0                 0
#                   placeSwitch                    0                 0
# 2148 auto   robot autoLine                       0                 0
#                   holdCube                       0                 0
#      finish robot disabled                       0                 0
#                   parkPlatform                   0                 0
#      teleop robot pickupCubeZone                 0                 0
#                   pickupFloor                    0                 0
#                   pickupPlatform                 0                 0
#
#                                   count_capabilities  avg_capabilities  \
# team phase  actor task
# 1318 auto   robot autoLine                        10               0.0
#                   crossNull                        2               0.0
#                   holdCube                        12               0.0
#                   placeIncorrect                   2               0.0
#                   placeScale                       2               0.0
#                   placeSwitch                      8               0.0
#      finish robot disabled                         6               0.0
#             team  getFoul                          2               0.0
#             robot makeClimb                        8               0.0
#                   parkPlatform                     2               0.0
#      teleop robot pickupCubeZone                   6               0.0
#                   pickupFloor                      8               0.0
#                   pickupPlatform                  10               0.0
#                   pickupPortal                     6               0.0
#                   placeOpponent                    4               0.0
#                   placeScale                      12               0.0
#                   placeSwitch                      6               0.0
# 2148 auto   robot autoLine                        10               0.0
#                   holdCube                         2               0.0
#      finish robot disabled                         2               0.0
#                   parkPlatform                     6               0.0
#      teleop robot pickupCubeZone                  12               0.0
#                   pickupFloor                      2               0.0
#                   pickupPlatform                   4               0.0
#
#                                   tav_capabilities
# team phase  actor task
# 1318 auto   robot autoLine                     0.0
#                   crossNull                    0.0
#                   holdCube                     0.0
#                   placeIncorrect               0.0
#                   placeScale                   0.0
#                   placeSwitch                  0.0
#      finish robot disabled                     0.0
#             team  getFoul                      0.0
#             robot makeClimb                    0.0
#                   parkPlatform                 0.0
#      teleop robot pickupCubeZone               0.0
#                   pickupFloor                  0.0
#                   pickupPlatform               0.0
#                   pickupPortal                 0.0
#                   placeOpponent                0.0
#                   placeScale                   0.0
#                   placeSwitch                  0.0
# 2148 auto   robot autoLine                     0.0
#                   holdCube                     0.0
#      finish robot disabled                     0.0
#                   parkPlatform                 0.0
#      teleop robot pickupCubeZone               0.0
#                   pickupFloor                  0.0
#                   pickupPlatform               0.0
#
# [24 rows x 25 columns]

# %%
len(mdf.index.levels[0])
# Out:
# 31

# %% [markdown]
# # Filter the Dataframe

# %%
scale_tele = mdf.xs(('teleop', 'robot', 'placeScale'),
                    level=[1, 2, 3])['avg_successes'].sort_values(ascending=False)
print(len(scale_tele))
scale_tele.head()
# Out:
# 27
# team
# 2811    3.333333
# 6831    3.166667
# 1318    2.833333
# 3588    2.166667
# 4980    1.666667
# Name: avg_successes, dtype: float64

# %% [markdown]
# # Plot the Data

# %%
# Extract an array of teams from the dataframe's index
teams = scale_tele.index.values

# Start a new plot and create the bar chart
p = bokeh.plotting.figure(x_range=teams, plot_width=700, plot_height=350)
p.vbar(x=teams, top=scale_tele, width=0.9)

# Text orientation is specified in radians, with zero radians being horizontal
p.xaxis.major_label_orientation = -3.14/4
# p.xaxis.axis_label = 'Team Number'
# p.yaxis.axis_label = 'Average Cubes per Match'

# Display the plot
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="efb78aff-e652-4cc9-900b-e0f92bdc5bef" data-root-id="1002"></div>

# %%
# Save plot to a file
res = bokeh.resources.Resources('relative', root_dir='.', )
bokeh.io.save(p, 'teleop_cubes2.html', res, 'Cubes Placed in Teleop2' )
# bokeh.io.output_file('teleop_cubes.html', title='Cubes Placed in Teleop', mode='relative', root_dir='.')
# bokeh.io.show(p)
# Out:
# 'C:\\Users\\stacy\\OneDrive\\Projects\\PythonClass\\19_files\\teleop_cubes2.html'

# %%
bokeh.io.export_png(p, 'teleop_cubes.png')
# Out:
# 'C:\\Users\\stacy\\OneDrive\\Projects\\PythonClass\\19_files\\teleop_cubes.png'

# %% [markdown]
# # Autonomous Version

# %%
scale_auto = mdf.xs(('auto', 'robot', 'placeScale'), level=[1, 2, 3])['avg_successes'].sort_values(ascending=False)
print(len(scale_auto))
scale_auto
# Out:
# 12
# team
# 2811    0.333333
# 3711    0.166667
# 1318    0.166667
# 5468    0.000000
# 4980    0.000000
# 4726    0.000000
# 3712    0.000000
# 3588    0.000000
# 3575    0.000000
# 3223    0.000000
# 3220    0.000000
# 3218    0.000000
# Name: avg_successes, dtype: float64

# %%
# Extract an array of teams from the dataframe's index
teams_auto = scale_auto.index.values

# Start a new plot and create the bar chart
p = bokeh.plotting.figure(title='Cubes Placed on Scale in Auto',
                          x_range=teams_auto, plot_width=700, plot_height=350)
p.vbar(x=teams_auto, top=scale_auto, width=0.8, fill_color='purple', line_color=None)
p.xaxis.major_label_orientation = -3.14/4
p.xaxis.axis_label = 'Team Number'
p.yaxis.axis_label = 'Average Cubes per Match'

# Display the plot
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="bf7b34bb-2418-4ece-8daf-0748407c6c6c" data-root-id="1250"></div>

# %% [markdown]
# # Stacked Bar Chart

# %%
scale_df = pd.concat([scale_auto, scale_tele], axis=1, sort=True)
scale_df.columns = ["avg_scale_auto", "avg_scale_tele"]
scale_df.head()
# Out:
#       avg_scale_auto  avg_scale_tele
# 1318        0.166667        2.833333
# 2148             NaN        0.000000
# 2522             NaN        0.833333
# 2811        0.333333        3.333333
# 2915             NaN        0.166667

# %%
scale_source = bokeh.models.ColumnDataSource(scale_df)
print('Column Names: ', scale_source.column_names)
print('Index values: ', scale_source.data['index'])
# Out:
# Column Names:  ['index', 'avg_scale_auto', 'avg_scale_tele']
# Index values:  ['1318' '2148' '2522' '2811' '2915' '2926' '2944' '3218' '3220' '3223'
#  '3575' '3586' '3588' '3693' '3711' '3712' '3826' '4061' '4120' '4125'
#  '4495' '4608' '4726' '4980' '5450' '5468' '6076' '6831']

# %%
p = bokeh.plotting.figure(title='Cubes Placed on Scale', x_range=scale_source.data['index'],
                          plot_width=700, plot_height=350)

p.vbar_stack(['avg_scale_tele', 'avg_scale_auto'], x='index',
             source=scale_source, color=['purple', 'gold'], width=0.8)

p.xaxis.major_label_orientation = -3.14/4
p.xaxis.axis_label = 'Team Number'
p.yaxis.axis_label = 'Average Cubes per Match'

# Display the plot
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="51490546-0874-48eb-a979-fc419951cfc0" data-root-id="1356"></div>

# %%
scale_df["avg_scale_total"] = scale_df["avg_scale_tele"] + scale_df["avg_scale_auto"]
scale_df.head()
# Out:
#       avg_scale_auto  avg_scale_tele  avg_scale_total
# 1318        0.166667        2.833333         3.000000
# 2148             NaN        0.000000              NaN
# 2522             NaN        0.833333              NaN
# 2811        0.333333        3.333333         3.666667
# 2915             NaN        0.166667              NaN

# %%
scale_df["avg_scale_total"] = scale_df["avg_scale_tele"].fillna(0) + scale_df["avg_scale_auto"].fillna(0)
scale_df.head()
# Out:
#       avg_scale_auto  avg_scale_tele  avg_scale_total
# 1318        0.166667        2.833333         3.000000
# 2148             NaN        0.000000         0.000000
# 2522             NaN        0.833333         0.833333
# 2811        0.333333        3.333333         3.666667
# 2915             NaN        0.166667         0.166667

# %%
scale_df.sort_values("avg_scale_total", ascending=False, inplace=True)

# %%
scale_df.head()
# Out:
#       avg_scale_auto  avg_scale_tele  avg_scale_total
# 2811        0.333333        3.333333         3.666667
# 6831             NaN        3.166667         3.166667
# 1318        0.166667        2.833333         3.000000
# 3588        0.000000        2.166667         2.166667
# 4980        0.000000        1.666667         1.666667

# %%
scale_source = bokeh.models.ColumnDataSource(scale_df)
print('Column Names: ', scale_source.column_names)
print('Index values: ', scale_source.data['index'])
# Out:
# Column Names:  ['index', 'avg_scale_auto', 'avg_scale_tele', 'avg_scale_total']
# Index values:  ['2811' '6831' '1318' '3588' '4980' '5450' '3826' '3711' '3218' '3220'
#  '4495' '4726' '2522' '4125' '2944' '4061' '3223' '5468' '2915' '3693'
#  '2148' '3586' '4120' '3575' '4608' '2926' '6076' '3712']

# %%
p = bokeh.plotting.figure(title='Cubes Placed on Scale', x_range=scale_source.data['index'],
                          plot_width=700, plot_height=350)

p.vbar_stack(['avg_scale_tele', 'avg_scale_auto'], x='index',
             source=scale_df, color=['purple', 'gold'], width=0.8,
            legend=['Teleop', 'Autonomous'])

p.xaxis.major_label_orientation = -3.14/4
p.xaxis.axis_label = 'Team Number'
p.yaxis.axis_label = 'Average Cubes per Match'

# Display the plot
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="8eafbb28-ca84-43d8-a2d1-7d4c7f711b17" data-root-id="1479"></div>

# %% [markdown]
# # Scatter Plot

# %%
swtch = mdf.xs(('teleop', 'placeSwitch'), level=[1, 3])['avg_successes']
swtch.index = swtch.index.droplevel(1)
swtch.head()
# Out:
# team
# 1318    0.166667
# 2148    0.500000
# 2522    0.000000
# 2811    1.000000
# 2915    0.666667
# Name: avg_successes, dtype: float64

# %%
scale = mdf.xs(('teleop', 'placeExchange'), level=[1,3])['avg_successes']
scale.index = scale.index.droplevel(1)
scale.head()
# Out:
# team
# 2148    1.666667
# 2811    3.000000
# 2926    2.000000
# 2944    0.333333
# 3218    1.000000
# Name: avg_successes, dtype: float64

# %%
ex_cl = pd.concat([swtch, scale], axis=1, sort=True)
ex_cl.columns=['avg_switch', 'avg_exchange']
ex_cl.head()
# Out:
#       avg_switch  avg_exchange
# 1318    0.166667           NaN
# 2148    0.500000      1.666667
# 2522    0.000000           NaN
# 2811    1.000000      3.000000
# 2915    0.666667           NaN

# %%
ex_cl_data = bokeh.models.ColumnDataSource(ex_cl)
print(ex_cl_data.column_names)
# Out:
# ['index', 'avg_switch', 'avg_exchange']

# %%
p = bokeh.plotting.figure(title='Switch vs Exchange Cubes Place')

p.circle(x='avg_switch', y='avg_exchange', source=ex_cl_data)
p.xaxis.axis_label = 'Average Cubes Placed on Switch'
p.yaxis.axis_label = 'Average Cubes to Exchange'

labels = bokeh.models.LabelSet(x='avg_switch', y='avg_exchange', text='index', source=ex_cl_data,
                              x_offset=5, y_offset=5)
p.add_layout(labels)

bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="2f076bc3-576c-4505-87fd-4d866d382542" data-root-id="1643"></div>

# %%
p = bokeh.plotting.figure(title='Switch vs Exchange Cubes Place', x_range=[0, 2], tooltips='@index')

p.circle(x='avg_switch', y='avg_exchange', source=ex_cl_data)
p.multi_line(xs=[[0, 1], [0, 2], [0, 3], [0, 4]], ys=[[1, 0], [2, 0], [3, 0], [4, 0]], color='red')
p.xaxis.axis_label = 'Average Cubes Placed on Switch'
p.yaxis.axis_label = 'Average Cubes to Exchange'

team_labels = bokeh.models.LabelSet(x='avg_switch', y='avg_exchange', text='index', source=ex_cl_data,
                              x_offset=5, y_offset=5)
p.add_layout(team_labels)
slope1_label = bokeh.models.Label(x=0.8, y=-0.1, text='1 cube/match', text_color='red')
p.add_layout(slope1_label)
slope2_label = bokeh.models.Label(x=1.3, y=0.4, text='2 cubes/match', text_color='red')
p.add_layout(slope2_label)
slope3_label = bokeh.models.Label(x=1.3, y=1.4, text='3 cubes/match', text_color='red')
p.add_layout(slope3_label)
slope4_label = bokeh.models.Label(x=1.3, y=2.45, text='4 cubes/match', text_color='red')
p.add_layout(slope4_label)

bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="4be97380-3df4-4a8b-943e-fde8b4a18422" data-root-id="1777"></div>
